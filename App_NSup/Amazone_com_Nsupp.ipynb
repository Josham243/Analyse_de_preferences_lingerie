# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#Importation du DataSet
dataset = pd.read_csv("C:\\Users\\Josham Kadiebwe\\Desktop\\python\\Datasets\\\Amazon.csv", sep=";")

# %%
dataset.head(30)
# Out:
#      mrp  price product_category  rating  review_count  Nylon  Rayon  Spandex  \
# 0   36.0  32.40             Bras     4.5            47     72      0        0
# 1   27.0  27.00          Panties     4.4            91     41      0       11
# 2   65.0  65.00             Bras     4.3           298      0      0        0
# 3   65.0  65.00             Bras     4.4           747     91      0        9
# 4   55.0  55.00             Bras     4.2           555      0      0       15
# 5   44.0  44.00             Bras     4.2           409     76      0        0
# 6   20.0  14.65          Panties     4.7           507      0      0        0
# 7   55.0  55.00             Bras     4.2           555      0      0       15
# 8   50.0  50.00             Bras     4.3           390     54      0       13
# 9   38.0  25.00             Bras     4.2           360     86      0       14
# 10  20.0  17.00          Panties     4.7           507      0      0        0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29048 entries, 0 to 29047
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   mrp               29048 non-null  float64
#  1   price             29048 non-null  float64
#  2   product_category  29048 non-null  object
#  3   rating            29048 non-null  float64
#  4   review_count      29048 non-null  int64
#  5   Nylon             29048 non-null  int64
#  6   Rayon             29048 non-null  int64
#  7   Spandex           29048 non-null  int64
#  8   polyester         29048 non-null  int64
#  9   Cotton            29048 non-null  int64
#  10  Modal             29048 non-null  int64
#  11  Elastane          29048 non-null  float64
# dtypes: float64(4), int64(7), object(1)
# memory usage: 2.7+ MB

# %%
dataset.nunique()
# Out:
# mrp                  517
# price               1508
# product_category       2
# rating                19
# review_count         298
# Nylon                 29
# Rayon                  2
# Spandex               24
# polyester              7
# Cotton                 5
# Modal                  2
# Elastane              20
# dtype: int64

# %%
dataset.shape
# Out:
# (29048, 12)

# %%
dataset.duplicated().shape
# Out:
# (29048,)

# %%
data=dataset.drop_duplicates(keep='last')
data.head()
# Out:
#       mrp  price product_category  rating  review_count  Nylon  Rayon  \
# 5   44.00  44.00             Bras     4.2           409     76      0
# 6   20.00  14.65          Panties     4.7           507      0      0
# 10  20.00  17.00          Panties     4.7           507      0      0
# 37  35.98  35.98          Panties     3.8            80     72      0
# 38  58.00  50.01             Bras     4.1             9     59      0
#
#     Spandex  polyester  Cotton  Modal  Elastane
# 5         0          0       0      0      24.0
# 6         0          0      53     35      12.0
# 10        0          0      53     35      12.0
# 37        0          0       0      0      28.0
# 38       41          0       0      0       0.0

# %%
data.shape
# Out:
# (4808, 12)

# %%
dataframe = data.reset_index(drop=True)
dataframe.head()
# Out:
#      mrp  price product_category  rating  review_count  Nylon  Rayon  Spandex  \
# 0  44.00  44.00             Bras     4.2           409     76      0        0
# 1  20.00  14.65          Panties     4.7           507      0      0        0
# 2  20.00  17.00          Panties     4.7           507      0      0        0
# 3  35.98  35.98          Panties     3.8            80     72      0        0
# 4  58.00  50.01             Bras     4.1             9     59      0       41
#
#    polyester  Cotton  Modal  Elastane
# 0          0       0      0      24.0
# 1          0      53     35      12.0
# 2          0      53     35      12.0
# 3          0       0      0      28.0
# 4          0       0      0       0.0

# %%
dataframe.isnull().sum()
# Out:
# mrp                 0
# price               0
# product_category    0
# rating              0
# review_count        0
# Nylon               0
# Rayon               0
# Spandex             0
# polyester           0
# Cotton              0
# Modal               0
# Elastane            0
# dtype: int64

# %%
dataframe.columns
# Out:
# Index(['mrp', 'price', 'product_category', 'rating', 'review_count', 'Nylon',
#        'Rayon', 'Spandex', 'polyester', 'Cotton', 'Modal', 'Elastane'],
#       dtype='object')

# %%
dataframe['product_category'].unique()
# Out:
# array(['Bras', 'Panties'], dtype=object)

# %%
dataframe.describe()
# Out:
#                mrp        price       rating  review_count       Nylon  \
# count  4808.000000  4808.000000  4808.000000   4808.000000  4808.00000
# mean     46.680605    37.642400     4.264871    453.984193    56.72109
# std      15.771251    15.252182     0.218224    467.192988    37.02250
# min       7.510000     5.000000     3.000000      1.000000     0.00000
# 25%      37.960000    25.000000     4.200000    106.000000     0.00000
# 50%      48.000000    36.950000     4.300000    377.000000    79.00000
# 75%      63.050000    48.425000     4.400000    530.000000    85.00000
# max      80.990000    80.990000     5.000000   1894.000000   100.00000
#
#              Rayon      Spandex    polyester       Cotton        Modal  \
# count  4808.000000  4808.000000  4808.000000  4808.000000  4808.000000
# mean      0.073835    11.984401    14.684692    10.772879     2.293053
# std       2.288655     9.469887    31.162038    27.318629     8.661084
# ...

# %% [markdown]
# # Visualisation de données

# %%
#corelation entre les données
sns.set(rc={'figure.figsize':(15,10)})

corelation=dataframe.corr()
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels = corelation.columns, annot=True, fmt='.0%')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(dataframe)

# %%
sns.relplot(x='Nylon', y='price', hue='rating', data=dataframe)

# %%
sns.relplot(x='review_count', y='price', hue='product_category', data=dataframe)

# %%
sns.relplot(x='Nylon', y='price', hue='product_category', data=dataframe)

# %%
datas =pd.get_dummies(dataframe, columns=['product_category'], drop_first=True)
datas.head()
# Out:
#      mrp  price  rating  review_count  Nylon  Rayon  Spandex  polyester  \
# 0  44.00  44.00     4.2           409     76      0        0          0
# 1  20.00  14.65     4.7           507      0      0        0          0
# 2  20.00  17.00     4.7           507      0      0        0          0
# 3  35.98  35.98     3.8            80     72      0        0          0
# 4  58.00  50.01     4.1             9     59      0       41          0
#
#    Cotton  Modal  Elastane  product_category_Panties
# 0       0      0      24.0                         0
# 1      53     35      12.0                         1
# 2      53     35      12.0                         1
# 3       0      0      28.0                         1
# 4       0      0       0.0                         0

# %%
cols = datas.columns
cols
# Out:
# Index(['mrp', 'price', 'rating', 'review_count', 'Nylon', 'Rayon', 'Spandex',
#        'polyester', 'Cotton', 'Modal', 'Elastane', 'product_category_Panties'],
#       dtype='object')

# %%
X_train = datas.iloc[:, 0:12].values
X_train.shape
# Out:
# (4808, 12)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scale = scaler.fit_transform(X_train)
X_scale.shape
# Out:
# (4808, 12)

# %%
X_train = pd.DataFrame(X_scale, columns =[cols])
X_train.shape
# Out:
# (4808, 12)

# %%
#determination du nombre de k(classes) avec la methodes du coude(Eblow en anglais)
from sklearn.cluster import KMeans

tab = []

for i in range (1,11):
    kmeans = KMeans(n_clusters = i, init='k-means++',random_state=42)
    kmeans = kmeans.fit(X_scale)
    tab.append(kmeans.inertia_)

# %%
#Visualiser Elbow
plt.plot(range(1,11), tab)
plt.title("La methode eblow")
plt.xlabel("Nombre de clusters")
plt.ylabel("Inertie")    
plt.show()

# %%
from sklearn.metrics import silhouette_samples, silhouette_score

kmeans = KMeans(n_clusters=2)
kmeans.fit(X_scale)
label = kmeans.predict(X_scale)

print("Silhouette Score(n=2):", silhouette_score(X_scale, label) )
# Out:
# Silhouette Score(n=2): 0.37221175881358726

# %%
from yellowbrick.cluster import KElbowVisualizer

model = KMeans(random_state=120)
#Instancie le KElbowVisualizer avec le nombre de clusters et la métrique

visualizer = KElbowVisualizer(model, metric='silhouette', timings=False)
plt.figure(figsize=(8,5))

visualizer.fit(X_scale)
visualizer.poof()
# Out:
# <AxesSubplot:title={'center':'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %%
colormap = np.array(["Red", "Blue"])
plt.scatter(dataframe.Nylon, dataframe.Spandex, c=colormap[kmeans.labels_],s=20)

# %%
colormap = np.array(["Red", "Blue"])
plt.scatter(dataframe.Cotton, dataframe.price, c=colormap[kmeans.labels_],s=20)

# %%
dataframe["Classe"] = kmeans.labels_
dataframe.head()
# Out:
#      mrp  price product_category  rating  review_count  Nylon  Rayon  Spandex  \
# 0  44.00  44.00             Bras     4.2           409     76      0        0
# 1  20.00  14.65          Panties     4.7           507      0      0        0
# 2  20.00  17.00          Panties     4.7           507      0      0        0
# 3  35.98  35.98          Panties     3.8            80     72      0        0
# 4  58.00  50.01             Bras     4.1             9     59      0       41
#
#    polyester  Cotton  Modal  Elastane  Classe
# 0          0       0      0      24.0       0
# 1          0      53     35      12.0       0
# 2          0      53     35      12.0       0
# 3          0       0      0      28.0       0
# 4          0       0      0       0.0       1

# %%
"""dataset = dataframe.drop(['Classes'], axis=1)"""
# Out:
# "dataset = dataframe.drop(['Classes'], axis=1)"

# %%
dataset=dataframe
dataframe.head()
# Out:
#      mrp  price product_category  rating  review_count  Nylon  Rayon  Spandex  \
# 0  44.00  44.00             Bras     4.2           409     76      0        0
# 1  20.00  14.65          Panties     4.7           507      0      0        0
# 2  20.00  17.00          Panties     4.7           507      0      0        0
# 3  35.98  35.98          Panties     3.8            80     72      0        0
# 4  58.00  50.01             Bras     4.1             9     59      0       41
#
#    polyester  Cotton  Modal  Elastane  Classe
# 0          0       0      0      24.0       0
# 1          0      53     35      12.0       0
# 2          0      53     35      12.0       0
# 3          0       0      0      28.0       0
# 4          0       0      0       0.0       1

# %%
dataset['Classe'].value_counts()
# Out:
# 1    3442
# 0    1366
# Name: Classe, dtype: int64

# %%
dataset.to_csv(path_or_buf='C:\\Users\\Josham Kadiebwe\\Desktop\\python\\Datasets\\Dataset2\\Amazon_com.csv',index=False)
